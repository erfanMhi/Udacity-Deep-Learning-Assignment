# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\envs\deeplearning\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
pickle_file = 'data/notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (9943, 28, 28) (9943,)
# Test set (9899, 28, 28) (9899,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (9943, 28, 28, 1) (9943, 10)
# Test set (9899, 28, 28, 1) (9899, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits_v2(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 4.566214
# Minibatch accuracy: 6.2%
# Validation accuracy: 9.4%
# Minibatch loss at step 50: 1.839420
# Minibatch accuracy: 31.2%
# Validation accuracy: 47.0%
# Minibatch loss at step 100: 1.012864
# Minibatch accuracy: 62.5%
# Validation accuracy: 67.9%
# Minibatch loss at step 150: 0.575258
# Minibatch accuracy: 75.0%
# Validation accuracy: 76.2%
# Minibatch loss at step 200: 0.849299
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.5%
# Minibatch loss at step 250: 1.188675
# Minibatch accuracy: 62.5%
# Validation accuracy: 77.4%
# Minibatch loss at step 300: 0.381973
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.1%
# Minibatch loss at step 350: 0.442074
# Minibatch accuracy: 93.8%
# Validation accuracy: 77.1%
# Minibatch loss at step 400: 0.354677
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.2%
# Minibatch loss at step 450: 0.853956
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.4%
# Minibatch loss at step 500: 0.818655
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.5%
# Minibatch loss at step 550: 0.866889
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.5%
# Minibatch loss at step 600: 0.335936
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.5%
# Minibatch loss at step 650: 0.793627
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.8%
# Minibatch loss at step 700: 0.900588
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.5%
# Minibatch loss at step 750: 0.093651
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.6%
# Minibatch loss at step 800: 0.551477
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.3%
# Minibatch loss at step 850: 0.817022
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.7%
# Minibatch loss at step 900: 0.778097
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.0%
# Minibatch loss at step 950: 0.648006
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.1%
# Minibatch loss at step 1000: 0.386541
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.9%
# Test accuracy: 89.8%

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %%
graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model_v2(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    max_pool = tf.nn.max_pool(conv, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(max_pool + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 1, 1, 1], padding='SAME')
    max_pool = tf.nn.max_pool(conv, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(max_pool + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model_v2(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits_v2(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model_v2(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model_v2(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.614510
# Minibatch accuracy: 18.8%
# Validation accuracy: 9.0%
# Minibatch loss at step 50: 2.257483
# Minibatch accuracy: 25.0%
# Validation accuracy: 12.1%
# Minibatch loss at step 100: 1.823537
# Minibatch accuracy: 31.2%
# Validation accuracy: 47.4%
# Minibatch loss at step 150: 0.651769
# Minibatch accuracy: 87.5%
# Validation accuracy: 66.9%
# Minibatch loss at step 200: 1.091475
# Minibatch accuracy: 62.5%
# Validation accuracy: 74.5%
# Minibatch loss at step 250: 1.426896
# Minibatch accuracy: 62.5%
# Validation accuracy: 75.5%
# Minibatch loss at step 300: 0.373916
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.7%
# Minibatch loss at step 350: 0.413992
# Minibatch accuracy: 93.8%
# Validation accuracy: 75.1%
# Minibatch loss at step 400: 0.208998
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.2%
# Minibatch loss at step 450: 1.066206
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.2%
# Minibatch loss at step 500: 0.781014
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.8%
# Minibatch loss at step 550: 0.624253
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.0%
# Minibatch loss at step 600: 0.408595
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.7%
# Minibatch loss at step 650: 0.962564
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.6%
# Minibatch loss at step 700: 0.691461
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.6%
# Minibatch loss at step 750: 0.077230
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.4%
# Minibatch loss at step 800: 0.622719
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.3%
# Minibatch loss at step 850: 0.823233
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.3%
# Minibatch loss at step 900: 0.714620
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.0%
# Minibatch loss at step 950: 0.659743
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.0%
# Minibatch loss at step 1000: 0.377528
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.9%
# Test accuracy: 89.8%

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %% [markdown]
# ## Lenet without dropout

# %%
batch_size = 16
kernel_size = 5
depth_1 = 6
depth_2 = 16
depth_3 = 120
num_hidden = 84


graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [kernel_size, kernel_size, num_channels, depth_1], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth_1]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [kernel_size, kernel_size, depth_1, depth_2], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth_2]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [kernel_size, kernel_size, depth_2, depth_3], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[depth_3]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [depth_3, num_hidden], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer5_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer5_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  # Model.
  def model_v3(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    max_pool = tf.nn.max_pool(conv, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(max_pool + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 1, 1, 1], padding='VALID')
    max_pool = tf.nn.max_pool(conv, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(max_pool + layer2_biases)
    conv = tf.nn.conv2d(hidden, layer3_weights, [1, 1, 1, 1], padding='VALID') + layer3_biases
    shape = conv.get_shape().as_list()
    reshape = tf.reshape(conv, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer4_weights) + layer4_biases)
    return tf.matmul(hidden, layer5_weights) + layer5_biases
  
  # Training computation.
  logits = model_v3(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits_v2(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model_v3(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model_v3(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 2.860345
# Minibatch accuracy: 0.0%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 2.120397
# Minibatch accuracy: 18.8%
# Validation accuracy: 38.0%
# Minibatch loss at step 100: 1.219291
# Minibatch accuracy: 62.5%
# Validation accuracy: 53.8%
# Minibatch loss at step 150: 0.830296
# Minibatch accuracy: 75.0%
# Validation accuracy: 68.6%
# Minibatch loss at step 200: 0.824670
# Minibatch accuracy: 75.0%
# Validation accuracy: 75.3%
# Minibatch loss at step 250: 1.148466
# Minibatch accuracy: 68.8%
# Validation accuracy: 76.8%
# Minibatch loss at step 300: 0.446641
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.2%
# Minibatch loss at step 350: 0.692385
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.7%
# Minibatch loss at step 400: 0.296022
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.7%
# Minibatch loss at step 450: 0.774474
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.2%
# Minibatch loss at step 500: 0.588156
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.9%
# Minibatch loss at step 550: 0.705644
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.7%
# Minibatch loss at step 600: 0.379142
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.5%
# Minibatch loss at step 650: 0.789250
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.8%
# Minibatch loss at step 700: 1.143838
# Minibatch accuracy: 62.5%
# Validation accuracy: 82.8%
# Minibatch loss at step 750: 0.040834
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.0%
# Minibatch loss at step 800: 0.581954
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.9%
# Minibatch loss at step 850: 0.782759
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.8%
# Minibatch loss at step 900: 0.552723
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.4%
# Minibatch loss at step 950: 0.697021
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.3%
# Minibatch loss at step 1000: 0.341536
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.5%
# Test accuracy: 90.1%

# %% [markdown]
# ## Lenet with dropout

# %%
graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [kernel_size, kernel_size, num_channels, depth_1], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth_1]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [kernel_size, kernel_size, depth_1, depth_2], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth_2]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [kernel_size, kernel_size, depth_2, depth_3], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[depth_3]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [depth_3, num_hidden], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer5_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer5_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  # Model.
  def model_v4(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    max_pool = tf.nn.max_pool(conv, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(max_pool + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 1, 1, 1], padding='VALID')
    max_pool = tf.nn.max_pool(conv, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(max_pool + layer2_biases)
    conv = tf.nn.conv2d(hidden, layer3_weights, [1, 1, 1, 1], padding='VALID') + layer3_biases
    shape = conv.get_shape().as_list()
    reshape = tf.reshape(conv, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer4_weights) + layer4_biases)
    dropout = tf.nn.dropout(hidden,.5)
    return tf.matmul(dropout, layer5_weights) + layer5_biases
  
  # Training computation.
  logits = model_v4(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits_v2(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model_v4(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model_v4(tf_test_dataset))

# %%
num_steps = 20001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.798380
# Minibatch accuracy: 0.0%
# Validation accuracy: 9.9%
# Minibatch loss at step 50: 2.315540
# Minibatch accuracy: 12.5%
# Validation accuracy: 14.3%
# Minibatch loss at step 100: 2.101048
# Minibatch accuracy: 18.8%
# Validation accuracy: 19.4%
# Minibatch loss at step 150: 1.864105
# Minibatch accuracy: 37.5%
# Validation accuracy: 30.9%
# Minibatch loss at step 200: 1.444343
# Minibatch accuracy: 56.2%
# Validation accuracy: 48.0%
# Minibatch loss at step 250: 1.640009
# Minibatch accuracy: 37.5%
# Validation accuracy: 57.4%
# Minibatch loss at step 300: 0.886930
# Minibatch accuracy: 62.5%
# Validation accuracy: 67.8%
# Minibatch loss at step 350: 0.646544
# Minibatch accuracy: 87.5%
# Validation accuracy: 69.2%
# Minibatch loss at step 400: 0.598102
# Minibatch accuracy: 81.2%
# Validation accuracy: 70.7%
# Minibatch loss at step 450: 1.067267
# Minibatch accuracy: 75.0%
# Validation accuracy: 71.4%
# Minibatch loss at step 500: 0.721095
# Minibatch accuracy: 81.2%
# Validation accuracy: 75.6%
# Minibatch loss at step 550: 1.203557
# Minibatch accuracy: 68.8%
# Validation accuracy: 75.7%
# Minibatch loss at step 600: 0.428668
# Minibatch accuracy: 87.5%
# Validation accuracy: 75.6%
# Minibatch loss at step 650: 0.838791
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.8%
# Minibatch loss at step 700: 0.748678
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.5%
# Minibatch loss at step 750: 0.154536
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.6%
# Minibatch loss at step 800: 0.796092
# Minibatch accuracy: 62.5%
# Validation accuracy: 72.0%
# Minibatch loss at step 850: 0.836205
# Minibatch accuracy: 68.8%
# Validation accuracy: 77.2%
# Minibatch loss at step 900: 0.798375
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.3%
# Minibatch loss at step 950: 0.649443
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.3%
# Minibatch loss at step 1000: 1.056769
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.2%
# Minibatch loss at step 1050: 1.122698
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.0%
# Minibatch loss at step 1100: 0.734584
# Minibatch accuracy: 68.8%
# Validation accuracy: 80.9%
# Minibatch loss at step 1150: 0.575061
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.9%
# Minibatch loss at step 1200: 1.119841
# Minibatch accuracy: 68.8%
# Validation accuracy: 78.2%
# Minibatch loss at step 1250: 0.598562
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.7%
# Minibatch loss at step 1300: 0.258175
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.2%
# Minibatch loss at step 1350: 0.920706
# Minibatch accuracy: 68.8%
# Validation accuracy: 80.0%
# Minibatch loss at step 1400: 0.379268
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.6%
# Minibatch loss at step 1450: 0.448507
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.2%
# Minibatch loss at step 1500: 0.907600
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.0%
# Minibatch loss at step 1550: 0.963649
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.2%
# Minibatch loss at step 1600: 0.792067
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.4%
# Minibatch loss at step 1650: 0.774725
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.3%
# Minibatch loss at step 1700: 0.507555
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.2%
# Minibatch loss at step 1750: 0.516135
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.8%
# Minibatch loss at step 1800: 0.398666
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.1%
# Minibatch loss at step 1850: 0.671908
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.9%
# Minibatch loss at step 1900: 0.509232
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.9%
# Minibatch loss at step 1950: 0.516746
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.9%
# Minibatch loss at step 2000: 0.379077
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.0%
# Minibatch loss at step 2050: 0.588706
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.0%
# Minibatch loss at step 2100: 0.424327
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.2%
# Minibatch loss at step 2150: 0.486300
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.6%
# Minibatch loss at step 2200: 0.227099
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.6%
# Minibatch loss at step 2250: 0.547485
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.1%
# Minibatch loss at step 2300: 0.657559
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.3%
# Minibatch loss at step 2350: 0.422231
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.1%
# Minibatch loss at step 2400: 0.529293
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.4%
# Minibatch loss at step 2450: 0.542021
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.8%
# Minibatch loss at step 2500: 0.908178
# Minibatch accuracy: 62.5%
# Validation accuracy: 82.4%
# Minibatch loss at step 2550: 0.692699
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.0%
# Minibatch loss at step 2600: 0.229899
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.4%
# Minibatch loss at step 2650: 0.337258
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.6%
# Minibatch loss at step 2700: 0.634374
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.0%
# Minibatch loss at step 2750: 1.045408
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.3%
# Minibatch loss at step 2800: 0.712336
# Minibatch accuracy: 68.8%
# Validation accuracy: 83.2%
# Minibatch loss at step 2850: 0.179586
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.5%
# Minibatch loss at step 2900: 0.331327
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.5%
# Minibatch loss at step 2950: 0.378704
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.3%
# Minibatch loss at step 3000: 0.754351
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.5%
# Minibatch loss at step 3050: 0.462702
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.6%
# Minibatch loss at step 3100: 0.387847
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.5%
# Minibatch loss at step 3150: 0.870623
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.7%
# Minibatch loss at step 3200: 0.498302
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.7%
# Minibatch loss at step 3250: 0.485409
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.6%
# Minibatch loss at step 3300: 0.065259
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.2%
# Minibatch loss at step 3350: 0.430118
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.7%
# Minibatch loss at step 3400: 0.744268
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.2%
# Minibatch loss at step 3450: 0.442950
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.0%
# Minibatch loss at step 3500: 0.560132
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.7%
# Minibatch loss at step 3550: 0.366024
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.5%
# Minibatch loss at step 3600: 0.059857
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.5%
# Minibatch loss at step 3650: 1.005776
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.1%
# Minibatch loss at step 3700: 1.168103
# Minibatch accuracy: 62.5%
# Validation accuracy: 83.8%
# Minibatch loss at step 3750: 1.000496
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.0%
# Minibatch loss at step 3800: 0.105141
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.3%
# Minibatch loss at step 3850: 0.509401
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.3%
# Minibatch loss at step 3900: 0.648549
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.7%
# Minibatch loss at step 3950: 0.026694
# Minibatch accuracy: 100.0%
# Validation accuracy: 84.3%
# Minibatch loss at step 4000: 0.419630
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.3%
# Minibatch loss at step 4050: 1.255287
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.6%
# Minibatch loss at step 4100: 0.704570
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.8%
# Minibatch loss at step 4150: 1.126774
# Minibatch accuracy: 56.2%
# Validation accuracy: 83.2%
# Minibatch loss at step 4200: 0.292626
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.7%
# Minibatch loss at step 4250: 0.327262
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.9%
# Minibatch loss at step 4300: 0.902519
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.3%
# Minibatch loss at step 4350: 0.310667
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.3%
# Minibatch loss at step 4400: 1.358618
# Minibatch accuracy: 56.2%
# Validation accuracy: 83.4%
# Minibatch loss at step 4450: 0.587415
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.2%
# Minibatch loss at step 4500: 0.689686
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.2%
# Minibatch loss at step 4550: 0.436314
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.8%
# Minibatch loss at step 4600: 0.524527
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.6%
# Minibatch loss at step 4650: 0.714756
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.2%
# Minibatch loss at step 4700: 0.450491
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.2%
# Minibatch loss at step 4750: 0.901745
# Minibatch accuracy: 68.8%
# Validation accuracy: 84.3%
# Minibatch loss at step 4800: 0.686977
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.5%
# Minibatch loss at step 4850: 0.427232
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.2%
# Minibatch loss at step 4900: 0.182969
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.8%
# Minibatch loss at step 4950: 0.327028
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.8%
# Minibatch loss at step 5000: 0.776035
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.1%
# Minibatch loss at step 5050: 0.417763
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.5%
# Minibatch loss at step 5100: 0.299443
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.4%
# Minibatch loss at step 5150: 0.528401
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.5%
# Minibatch loss at step 5200: 0.575493
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.5%
# Minibatch loss at step 5250: 0.146998
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.8%
# Minibatch loss at step 5300: 0.221821
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.9%
# Minibatch loss at step 5350: 0.358176
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.6%
# Minibatch loss at step 5400: 0.403897
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.1%
# Minibatch loss at step 5450: 0.296137
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.0%
# Minibatch loss at step 5500: 0.570387
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.3%
# Minibatch loss at step 5550: 0.285724
# Minibatch accuracy: 100.0%
# Validation accuracy: 84.6%
# Minibatch loss at step 5600: 0.334532
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.1%
# Minibatch loss at step 5650: 0.424265
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.8%
# Minibatch loss at step 5700: 0.377929
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.7%
# Minibatch loss at step 5750: 0.683946
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.7%
# Minibatch loss at step 5800: 0.290419
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.9%
# Minibatch loss at step 5850: 0.795139
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.8%
# Minibatch loss at step 5900: 0.672809
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.8%
# Minibatch loss at step 5950: 0.384087
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.4%
# Minibatch loss at step 6000: 0.255421
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.1%
# Minibatch loss at step 6050: 0.586475
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.9%
# Minibatch loss at step 6100: 0.603859
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.9%
# Minibatch loss at step 6150: 0.140145
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.4%
# Minibatch loss at step 6200: 1.195290
# Minibatch accuracy: 62.5%
# Validation accuracy: 84.9%
# Minibatch loss at step 6250: 0.848192
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.7%
# Minibatch loss at step 6300: 0.734613
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.4%
# Minibatch loss at step 6350: 0.283540
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.2%
# Minibatch loss at step 6400: 0.112518
# Minibatch accuracy: 100.0%
# Validation accuracy: 84.5%
# Minibatch loss at step 6450: 0.411124
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.7%
# Minibatch loss at step 6500: 0.716245
# Minibatch accuracy: 68.8%
# Validation accuracy: 85.3%
# Minibatch loss at step 6550: 0.460017
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.4%
# Minibatch loss at step 6600: 0.424590
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.0%
# Minibatch loss at step 6650: 1.889213
# Minibatch accuracy: 62.5%
# Validation accuracy: 84.5%
# Minibatch loss at step 6700: 0.200429
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.8%
# Minibatch loss at step 6750: 0.548026
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.0%
# Minibatch loss at step 6800: 0.694998
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.3%
# Minibatch loss at step 6850: 0.737426
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.3%
# Minibatch loss at step 6900: 0.979242
# Minibatch accuracy: 62.5%
# Validation accuracy: 85.3%
# Minibatch loss at step 6950: 0.372363
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.2%
# Minibatch loss at step 7000: 0.757318
# Minibatch accuracy: 68.8%
# Validation accuracy: 84.9%
# Minibatch loss at step 7050: 0.571239
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.8%
# Minibatch loss at step 7100: 0.576119
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.7%
# Minibatch loss at step 7150: 0.185592
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.1%
# Minibatch loss at step 7200: 0.593796
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.0%
# Minibatch loss at step 7250: 0.620446
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.0%
# Minibatch loss at step 7300: 0.949466
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.9%
# Minibatch loss at step 7350: 0.265519
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.5%
# Minibatch loss at step 7400: 0.042777
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.8%
# Minibatch loss at step 7450: 0.463721
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.4%
# Minibatch loss at step 7500: 0.218825
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.7%
# Minibatch loss at step 7550: 0.676788
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.7%
# Minibatch loss at step 7600: 0.556260
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.2%
# Minibatch loss at step 7650: 0.258167
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.0%
# Minibatch loss at step 7700: 0.336858
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.9%
# Minibatch loss at step 7750: 0.791555
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.4%
# Minibatch loss at step 7800: 0.497195
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.6%
# Minibatch loss at step 7850: 0.704199
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.0%
# Minibatch loss at step 7900: 0.160045
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.6%
# Minibatch loss at step 7950: 1.126809
# Minibatch accuracy: 68.8%
# Validation accuracy: 85.2%
# Minibatch loss at step 8000: 0.353672
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.3%
# Minibatch loss at step 8050: 0.279538
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.5%
# Minibatch loss at step 8100: 0.560961
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.2%
# Minibatch loss at step 8150: 0.473109
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.7%
# Minibatch loss at step 8200: 0.527714
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.1%
# Minibatch loss at step 8250: 0.250775
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.8%
# Minibatch loss at step 8300: 0.232350
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.0%
# Minibatch loss at step 8350: 0.746851
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.7%
# Minibatch loss at step 8400: 0.323993
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.7%
# Minibatch loss at step 8450: 0.264739
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.6%
# Minibatch loss at step 8500: 0.287815
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.0%
# Minibatch loss at step 8550: 0.413377
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.6%
# Minibatch loss at step 8600: 0.539189
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.2%
# Minibatch loss at step 8650: 0.652858
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.7%
# Minibatch loss at step 8700: 0.260516
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.2%
# Minibatch loss at step 8750: 0.261075
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.0%
# Minibatch loss at step 8800: 0.325273
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.6%
# Minibatch loss at step 8850: 0.012517
# Minibatch accuracy: 100.0%
# Validation accuracy: 84.5%
# Minibatch loss at step 8900: 0.714762
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.9%
# Minibatch loss at step 8950: 0.366774
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.3%
# Minibatch loss at step 9000: 0.678077
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.2%
# Minibatch loss at step 9050: 0.469057
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.4%
# Minibatch loss at step 9100: 0.409368
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.2%
# Minibatch loss at step 9150: 0.786444
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.4%
# Minibatch loss at step 9200: 0.238334
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.9%
# Minibatch loss at step 9250: 0.835998
# Minibatch accuracy: 68.8%
# Validation accuracy: 85.7%
# Minibatch loss at step 9300: 0.951027
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.3%
# Minibatch loss at step 9350: 0.367042
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.5%
# Minibatch loss at step 9400: 0.443956
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.3%
# Minibatch loss at step 9450: 0.452388
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.5%
# Minibatch loss at step 9500: 0.080248
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.0%
# Minibatch loss at step 9550: 0.251916
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.6%
# Minibatch loss at step 9600: 0.426776
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.6%
# Minibatch loss at step 9650: 0.640466
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.8%
# Minibatch loss at step 9700: 0.295355
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.3%
# Minibatch loss at step 9750: 0.174664
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.5%
# Minibatch loss at step 9800: 0.672146
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.7%
# Minibatch loss at step 9850: 0.134754
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.6%
# Minibatch loss at step 9900: 0.501678
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.4%
# Minibatch loss at step 9950: 0.361179
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.4%
# Minibatch loss at step 10000: 0.431944
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.0%
# Minibatch loss at step 10050: 0.079081
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.6%
# Minibatch loss at step 10100: 0.285545
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.7%
# Minibatch loss at step 10150: 0.729929
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.7%
# Minibatch loss at step 10200: 0.144971
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.7%
# Minibatch loss at step 10250: 0.392849
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.2%
# Minibatch loss at step 10300: 0.309428
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.3%
# Minibatch loss at step 10350: 0.884219
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.4%
# Minibatch loss at step 10400: 0.401910
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.5%
# Minibatch loss at step 10450: 0.246884
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.1%
# Minibatch loss at step 10500: 0.337295
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.3%
# Minibatch loss at step 10550: 0.837407
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.0%
# Minibatch loss at step 10600: 0.454810
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.2%
# Minibatch loss at step 10650: 0.572771
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.0%
# Minibatch loss at step 10700: 0.099410
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.1%
# Minibatch loss at step 10750: 0.312148
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.8%
# Minibatch loss at step 10800: 0.911934
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.6%
# Minibatch loss at step 10850: 1.121224
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.9%
# Minibatch loss at step 10900: 0.356472
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.5%
# Minibatch loss at step 10950: 0.484438
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.1%
# Minibatch loss at step 11000: 0.099156
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.2%
# Minibatch loss at step 11050: 0.796090
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.0%
# Minibatch loss at step 11100: 0.190755
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.2%
# Minibatch loss at step 11150: 0.353988
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.9%
# Minibatch loss at step 11200: 0.402151
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.3%
# Minibatch loss at step 11250: 1.625096
# Minibatch accuracy: 62.5%
# Validation accuracy: 86.2%
# Minibatch loss at step 11300: 0.360695
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.4%
# Minibatch loss at step 11350: 0.353552
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.0%
# Minibatch loss at step 11400: 0.158348
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.1%
# Minibatch loss at step 11450: 0.309858
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.2%
# Minibatch loss at step 11500: 0.457424
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.4%
# Minibatch loss at step 11550: 0.345920
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.7%
# Minibatch loss at step 11600: 0.491696
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.0%
# Minibatch loss at step 11650: 0.473007
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.5%
# Minibatch loss at step 11700: 0.941134
# Minibatch accuracy: 68.8%
# Validation accuracy: 85.9%
# Minibatch loss at step 11750: 0.629877
# Minibatch accuracy: 68.8%
# Validation accuracy: 85.6%
# Minibatch loss at step 11800: 0.134487
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.1%
# Minibatch loss at step 11850: 0.762355
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.7%
# Minibatch loss at step 11900: 0.604702
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.1%
# Minibatch loss at step 11950: 0.850925
# Minibatch accuracy: 68.8%
# Validation accuracy: 85.8%
# Minibatch loss at step 12000: 0.451239
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.8%
# Minibatch loss at step 12050: 0.169831
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.1%
# Minibatch loss at step 12100: 0.592317
# Minibatch accuracy: 68.8%
# Validation accuracy: 86.1%
# Minibatch loss at step 12150: 0.205486
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.1%
# Minibatch loss at step 12200: 0.410450
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.8%
# Minibatch loss at step 12250: 0.415173
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.9%
# Minibatch loss at step 12300: 0.563386
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.6%
# Minibatch loss at step 12350: 1.056010
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.4%
# Minibatch loss at step 12400: 0.128743
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.0%
# Minibatch loss at step 12450: 0.983562
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.2%
# Minibatch loss at step 12500: 0.690386
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.0%
# Minibatch loss at step 12550: 0.631753
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.9%
# Minibatch loss at step 12600: 0.587553
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.7%
# Minibatch loss at step 12650: 0.830050
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.0%
# Minibatch loss at step 12700: 0.366053
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.6%
# Minibatch loss at step 12750: 0.205574
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.3%
# Minibatch loss at step 12800: 0.154484
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.2%
# Minibatch loss at step 12850: 0.251632
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.0%
# Minibatch loss at step 12900: 0.305620
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.9%
# Minibatch loss at step 12950: 0.170887
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.9%
# Minibatch loss at step 13000: 0.295925
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.1%
# Minibatch loss at step 13050: 0.440145
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.8%
# Minibatch loss at step 13100: 0.183162
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.2%
# Minibatch loss at step 13150: 0.457855
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.6%
# Minibatch loss at step 13200: 0.432109
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.3%
# Minibatch loss at step 13250: 0.987330
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.8%
# Minibatch loss at step 13300: 0.236385
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.2%
# Minibatch loss at step 13350: 0.311404
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.3%
# Minibatch loss at step 13400: 0.823345
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.2%
# Minibatch loss at step 13450: 0.436343
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.5%
# Minibatch loss at step 13500: 0.405594
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.9%
# Minibatch loss at step 13550: 0.848324
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.9%
# Minibatch loss at step 13600: 0.265241
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.7%
# Minibatch loss at step 13650: 0.460209
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.9%
# Minibatch loss at step 13700: 0.531771
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.9%
# Minibatch loss at step 13750: 0.867151
# Minibatch accuracy: 68.8%
# Validation accuracy: 85.8%
# Minibatch loss at step 13800: 0.083266
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.4%
# Minibatch loss at step 13850: 0.493179
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.6%
# Minibatch loss at step 13900: 0.238852
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.3%
# Minibatch loss at step 13950: 0.470004
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.2%
# Minibatch loss at step 14000: 0.074924
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.0%
# Minibatch loss at step 14050: 0.312766
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.8%
# Minibatch loss at step 14100: 0.554751
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.3%
# Minibatch loss at step 14150: 0.521241
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.2%
# Minibatch loss at step 14200: 0.341889
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.6%
# Minibatch loss at step 14250: 0.470805
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.7%
# Minibatch loss at step 14300: 0.579499
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.9%
# Minibatch loss at step 14350: 0.079218
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.8%
# Minibatch loss at step 14400: 0.402372
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.3%
# Minibatch loss at step 14450: 0.184462
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.3%
# Minibatch loss at step 14500: 0.562951
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.8%
# Minibatch loss at step 14550: 0.385621
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.0%
# Minibatch loss at step 14600: 0.083403
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.1%
# Minibatch loss at step 14650: 0.673880
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.7%
# Minibatch loss at step 14700: 0.366704
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.1%
# Minibatch loss at step 14750: 0.333766
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.4%
# Minibatch loss at step 14800: 0.604912
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.8%
# Minibatch loss at step 14850: 0.362055
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.4%
# Minibatch loss at step 14900: 0.572839
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.9%
# Minibatch loss at step 14950: 0.446700
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.8%
# Minibatch loss at step 15000: 0.838982
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.0%
# Minibatch loss at step 15050: 0.476324
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.4%
# Minibatch loss at step 15100: 0.302288
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.5%
# Minibatch loss at step 15150: 0.501390
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.0%
# Minibatch loss at step 15200: 0.163485
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.7%
# Minibatch loss at step 15250: 0.622036
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.6%
# Minibatch loss at step 15300: 0.201214
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.9%
# Minibatch loss at step 15350: 0.214221
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.3%
# Minibatch loss at step 15400: 0.979097
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.5%
# Minibatch loss at step 15450: 0.786099
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.3%
# Minibatch loss at step 15500: 0.214536
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.5%
# Minibatch loss at step 15550: 0.393441
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.2%
# Minibatch loss at step 15600: 0.564745
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.1%
# Minibatch loss at step 15650: 0.365793
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.1%
# Minibatch loss at step 15700: 0.279811
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.1%
# Minibatch loss at step 15750: 0.218469
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.6%
# Minibatch loss at step 15800: 0.441641
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.4%
# Minibatch loss at step 15850: 0.326702
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.4%
# Minibatch loss at step 15900: 0.724950
# Minibatch accuracy: 68.8%
# Validation accuracy: 86.7%
# Minibatch loss at step 15950: 0.126630
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.7%
# Minibatch loss at step 16000: 0.888260
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.2%
# Minibatch loss at step 16050: 0.134850
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.9%
# Minibatch loss at step 16100: 0.454949
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.3%
# Minibatch loss at step 16150: 0.062849
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.0%
# Minibatch loss at step 16200: 0.716032
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.9%
# Minibatch loss at step 16250: 0.437253
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.4%
# Minibatch loss at step 16300: 0.640023
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.6%
# Minibatch loss at step 16350: 0.593898
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.7%
# Minibatch loss at step 16400: 0.862917
# Minibatch accuracy: 68.8%
# Validation accuracy: 86.2%
# Minibatch loss at step 16450: 0.713242
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.1%
# Minibatch loss at step 16500: 0.029833
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.2%
# Minibatch loss at step 16550: 0.489322
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.2%
# Minibatch loss at step 16600: 0.316470
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.6%
# Minibatch loss at step 16650: 0.946398
# Minibatch accuracy: 62.5%
# Validation accuracy: 86.4%
# Minibatch loss at step 16700: 0.546607
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.7%
# Minibatch loss at step 16750: 0.590393
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.0%
# Minibatch loss at step 16800: 0.673604
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.2%
# Minibatch loss at step 16850: 0.715304
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.4%
# Minibatch loss at step 16900: 1.169077
# Minibatch accuracy: 68.8%
# Validation accuracy: 86.1%
# Minibatch loss at step 16950: 0.221355
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.1%
# Minibatch loss at step 17000: 0.212697
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.5%
# Minibatch loss at step 17050: 0.324223
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.8%
# Minibatch loss at step 17100: 0.163802
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.3%
# Minibatch loss at step 17150: 0.218377
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.4%
# Minibatch loss at step 17200: 0.319130
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.3%
# Minibatch loss at step 17250: 0.614494
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.0%
# Minibatch loss at step 17300: 0.376405
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.0%
# Minibatch loss at step 17350: 0.326761
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.4%
# Minibatch loss at step 17400: 0.473413
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.6%
# Minibatch loss at step 17450: 0.231425
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.1%
# Minibatch loss at step 17500: 0.440541
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.2%
# Minibatch loss at step 17550: 0.510129
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.4%
# Minibatch loss at step 17600: 0.980164
# Minibatch accuracy: 68.8%
# Validation accuracy: 86.0%
# Minibatch loss at step 17650: 0.303226
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.0%
# Minibatch loss at step 17700: 0.744622
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.0%
# Minibatch loss at step 17750: 0.271320
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.6%
# Minibatch loss at step 17800: 0.478083
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.4%
# Minibatch loss at step 17850: 0.460973
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.9%
# Minibatch loss at step 17900: 0.596248
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.7%
# Minibatch loss at step 17950: 0.472151
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.0%
# Minibatch loss at step 18000: 0.352390
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.2%
# Minibatch loss at step 18050: 0.490199
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.5%
# Minibatch loss at step 18100: 0.739036
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.7%
# Minibatch loss at step 18150: 0.253280
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.4%
# Minibatch loss at step 18200: 0.733203
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.3%
# Minibatch loss at step 18250: 0.423068
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.7%
# Minibatch loss at step 18300: 0.194307
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.3%
# Minibatch loss at step 18350: 0.416603
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.7%
# Minibatch loss at step 18400: 0.892144
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.7%
# Minibatch loss at step 18450: 0.334024
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.3%
# Minibatch loss at step 18500: 0.433529
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.2%
# Minibatch loss at step 18550: 0.628511
# Minibatch accuracy: 68.8%
# Validation accuracy: 86.2%
# Minibatch loss at step 18600: 0.138996
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.7%
# Minibatch loss at step 18650: 0.305132
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.9%
# Minibatch loss at step 18700: 0.257728
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.8%
# Minibatch loss at step 18750: 0.594211
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.3%
# Minibatch loss at step 18800: 0.403464
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.8%
# Minibatch loss at step 18850: 0.521559
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.5%
# Minibatch loss at step 18900: 0.026694
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.0%
# Minibatch loss at step 18950: 0.169141
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.6%
# Minibatch loss at step 19000: 0.780137
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.1%
# Minibatch loss at step 19050: 0.048292
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.4%
# Minibatch loss at step 19100: 0.059061
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.9%
# Minibatch loss at step 19150: 0.471321
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.4%
# Minibatch loss at step 19200: 0.354567
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.9%
# Minibatch loss at step 19250: 0.934082
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.2%
# Minibatch loss at step 19300: 0.192557
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.7%
# Minibatch loss at step 19350: 0.272015
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.9%
# Minibatch loss at step 19400: 0.738929
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.6%
# Minibatch loss at step 19450: 0.266994
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.7%
# Minibatch loss at step 19500: 0.483030
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.4%
# Minibatch loss at step 19550: 0.456130
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.7%
# Minibatch loss at step 19600: 0.550907
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.5%
# Minibatch loss at step 19650: 0.466088
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.1%
# Minibatch loss at step 19700: 0.332654
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.1%
# Minibatch loss at step 19750: 0.946469
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.9%
# Minibatch loss at step 19800: 0.352983
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.4%
# Minibatch loss at step 19850: 0.296125
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.5%
# Minibatch loss at step 19900: 0.070610
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.9%
# Minibatch loss at step 19950: 0.657225
# Minibatch accuracy: 68.8%
# Validation accuracy: 86.9%
# Minibatch loss at step 20000: 0.273354
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.5%
# Test accuracy: 92.9%
