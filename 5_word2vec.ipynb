# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\envs\deeplearning\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'
data_root = 'text_data'
def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""

  if not os.path.exists(os.path.join(data_root,filename)):
    filename, _ = urlretrieve(url + filename, os.path.join(data_root,filename))
  else :
    filename = os.path.join(data_root,filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text_data\text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data
# Out:
# [5234,
#  3081,
#  12,
#  6,
#  195,
#  2,
#  3134,
#  46,
#  59,
#  156,
#  128,
#  742,
#  477,
#  10572,
#  134,
#  1,
#  27350,
#  2,
#  1,
#  103,
#  855,
#  3,
#  1,
#  15068,
#  0,
#  2,
#  1,
#  151,
#  855,
#  3581,
#  1,
#  195,
#  11,
#  191,
#  59,
#  5,
#  6,
#  10713,
#  215,
#  7,
#  1325,
#  105,
#  455,
#  20,
#  59,
#  2732,
#  363,
#  7,
#  3673,
#  1,
#  709,
#  2,
#  372,
#  27,
#  41,
#  37,
#  54,
#  540,
#  98,
#  12,
#  6,
#  1424,
#  2758,
#  19,
#  568,
#  687,
#  7089,
#  1,
#  248,
#  5234,
#  11,
#  1053,
#  28,
#  1,
#  321,
#  249,
#  44612,
#  2878,
#  793,
#  187,
#  5234,
#  12,
#  6,
#  201,
#  603,
#  11,
#  1,
#  1135,
#  20,
#  2622,
#  26,
#  8984,
#  3,
#  280,
#  32,
#  4148,
#  142,
#  60,
#  26,
#  6438,
#  4187,
#  2,
#  154,
#  33,
#  363,
#  5234,
#  37,
#  1138,
#  7,
#  448,
#  345,
#  1819,
#  20,
#  4861,
#  1,
#  6754,
#  2,
#  7574,
#  1775,
#  567,
#  1,
#  94,
#  1,
#  248,
#  11065,
#  12,
#  52,
#  7089,
#  90,
#  27,
#  271,
#  38,
#  5949,
#  4862,
#  20300,
#  29,
#  0,
#  42,
#  318,
#  6,
#  25637,
#  528,
#  7574,
#  372,
#  5,
#  259,
#  2,
#  154,
#  26,
#  1207,
#  12,
#  7574,
#  201,
#  1577,
#  3,
#  15201,
#  333,
#  1775,
#  7089,
#  4861,
#  345,
#  765,
#  161,
#  407,
#  5691,
#  756,
#  2,
#  4106,
#  1132,
#  4332,
#  1537,
#  3,
#  568,
#  8118,
#  99,
#  5234,
#  11,
#  52,
#  1408,
#  687,
#  19,
#  154,
#  27,
#  11,
#  156,
#  7089,
#  37,
#  2034,
#  1424,
#  8175,
#  2,
#  154,
#  47,
#  694,
#  7,
#  32,
#  6,
#  4149,
#  247,
#  372,
#  77,
#  949,
#  79,
#  311,
#  31,
#  4779,
#  372,
#  508,
#  140,
#  2313,
#  3554,
#  365,
#  24,
#  1822,
#  7,
#  1903,
#  60,
#  11,
#  37,
#  8400,
#  79,
#  311,
#  6,
#  247,
#  372,
#  508,
#  32,
#  754,
#  79,
#  1733,
#  3,
#  8041,
#  24173,
#  3,
#  276,
#  1694,
#  20,
#  152,
#  1033,
#  96,
#  225,
#  372,
#  18,
#  1814,
#  25,
#  4779,
#  1557,
#  52,
#  8119,
#  1466,
#  24173,
#  3,
#  12744,
#  5,
#  6131,
#  20,
#  4188,
#  21149,
#  2428,
#  40,
#  16456,
#  3,
#  7240,
#  862,
#  2,
#  1194,
#  10208,
#  2515,
#  29,
#  15069,
#  188,
#  3,
#  49,
#  1124,
#  913,
#  7,
#  1050,
#  468,
#  12298,
#  7089,
#  134,
#  1,
#  1,
#  11065,
#  3056,
#  3,
#  12061,
#  735,
#  4779,
#  6599,
#  5,
#  14623,
#  28,
#  451,
#  486,
#  24173,
#  199,
#  296,
#  949,
#  5,
#  20028,
#  20301,
#  2,
#  0,
#  301,
#  7,
#  24173,
#  20301,
#  16457,
#  1,
#  30107,
#  2,
#  1,
#  94,
#  45,
#  3833,
#  3,
#  0,
#  3,
#  3808,
#  1,
#  3413,
#  2,
#  1,
#  1777,
#  188,
#  2,
#  1,
#  626,
#  1,
#  13142,
#  2,
#  4,
#  22,
#  91,
#  123,
#  285,
#  26,
#  244,
#  233,
#  7,
#  32,
#  437,
#  26185,
#  2,
#  174,
#  5234,
#  7700,
#  2535,
#  5,
#  30,
#  96,
#  2,
#  290,
#  603,
#  4309,
#  20,
#  1,
#  13142,
#  16457,
#  50,
#  188,
#  118,
#  47,
#  360,
#  20,
#  1,
#  385,
#  243,
#  97,
#  32,
#  5235,
#  35,
#  332,
#  2724,
#  19,
#  1,
#  839,
#  1377,
#  28,
#  33,
#  8762,
#  47,
#  6471,
#  35,
#  3244,
#  1,
#  27350,
#  29,
#  552,
#  42433,
#  40,
#  31,
#  128,
#  0,
#  436,
#  85,
#  1,
#  65,
#  2,
#  1,
#  103,
#  463,
#  84,
#  3,
#  26,
#  233,
#  19,
#  48,
#  12,
#  26185,
#  2,
#  174,
#  5234,
#  5,
#  1,
#  174,
#  840,
#  1,
#  46,
#  7,
#  90,
#  1,
#  195,
#  7,
#  1015,
#  1044,
#  43,
#  70,
#  4862,
#  18,
#  937,
#  14921,
#  4572,
#  165,
#  0,
#  5,
#  30,
#  40562,
#  11816,
#  22893,
#  260,
#  1226,
#  0,
#  0,
#  4,
#  23,
#  8,
#  17,
#  100,
#  36,
#  629,
#  1,
#  2663,
#  64,
#  372,
#  34,
#  49,
#  76,
#  94,
#  688,
#  14778,
#  4045,
#  29,
#  818,
#  918,
#  12,
#  102,
#  5,
#  11065,
#  2535,
#  363,
#  6,
#  6055,
#  3,
#  663,
#  5,
#  1,
#  64,
#  702,
#  436,
#  41,
#  4219,
#  1290,
#  20,
#  36,
#  11,
#  31,
#  4779,
#  3,
#  95,
#  26,
#  50,
#  30,
#  5213,
#  5,
#  4,
#  23,
#  9,
#  17,
#  5,
#  1,
#  5349,
#  2,
#  1,
#  151,
#  855,
#  468,
#  12298,
#  335,
#  31,
#  17195,
#  2435,
#  201,
#  1294,
#  142,
#  12298,
#  216,
#  38,
#  90,
#  1,
#  248,
#  5234,
#  56,
#  117,
#  7089,
#  39,
#  1207,
#  33,
#  198,
#  12,
#  1,
#  46,
#  182,
#  4779,
#  530,
#  3,
#  12298,
#  12,
#  1,
#  1835,
#  2,
#  1913,
#  5234,
#  42,
#  35,
#  33,
#  229,
#  76,
#  4779,
#  436,
#  734,
#  2400,
#  3,
#  1,
#  195,
#  0,
#  18,
#  87,
#  1074,
#  12,
#  31,
#  14023,
#  30108,
#  19,
#  1,
#  12062,
#  0,
#  35,
#  51,
#  2420,
#  617,
#  5,
#  1,
#  151,
#  855,
#  1,
#  46,
#  568,
#  8717,
#  4779,
#  2936,
#  1034,
#  14498,
#  27,
#  11,
#  637,
#  360,
#  20,
#  27,
#  5386,
#  155,
#  192,
#  2936,
#  1034,
#  14498,
#  335,
#  154,
#  11,
#  918,
#  5,
#  4,
#  13,
#  21,
#  8,
#  20,
#  1,
#  195,
#  4779,
#  18,
#  990,
#  12,
#  6,
#  568,
#  1607,
#  27,
#  11,
#  14,
#  33,
#  891,
#  20,
#  48,
#  849,
#  14498,
#  12,
#  1,
#  1835,
#  2,
#  174,
#  4779,
#  209,
#  5,
#  154,
#  11,
#  918,
#  14498,
#  5464,
#  24,
#  1,
#  420,
#  12954,
#  918,
#  11,
#  6879,
#  5,
#  33,
#  140,
#  36,
#  1347,
#  1,
#  2879,
#  2,
#  15069,
#  918,
#  0,
#  155,
#  100,
#  3466,
#  39,
#  653,
#  446,
#  7,
#  90,
#  3,
#  3134,
#  44,
#  918,
#  12,
#  47,
#  3592,
#  55,
#  12,
#  15348,
#  1556,
#  14,
#  2966,
#  5,
#  45,
#  259,
#  14498,
#  1165,
#  154,
#  36,
#  89,
#  3222,
#  1132,
#  53,
#  39,
#  752,
#  446,
#  7,
#  90,
#  1050,
#  523,
#  3,
#  1792,
#  5,
#  5806,
#  24,
#  1557,
#  2,
#  5129,
#  3,
#  1294,
#  14498,
#  15,
#  2655,
#  2,
#  11065,
#  34,
#  36,
#  89,
#  29373,
#  0,
#  967,
#  31,
#  1335,
#  519,
#  100,
#  1132,
#  3,
#  309,
#  160,
#  513,
#  1,
#  806,
#  2,
#  44,
#  1259,
#  219,
#  1259,
#  1038,
#  34,
#  1392,
#  1,
#  909,
#  2,
#  742,
#  65,
#  967,
#  5,
#  443,
#  33,
#  74,
#  2914,
#  20,
#  76,
#  4,
#  74,
#  2966,
#  28,
#  1,
#  1259,
#  2,
#  276,
#  1556,
#  160,
#  4320,
#  2519,
#  499,
#  5,
#  728,
#  10639,
#  18742,
#  31,
#  763,
#  247,
#  987,
#  74,
#  32,
#  178,
#  98,
#  7,
#  741,
#  3273,
#  24,
#  913,
#  7,
#  1,
#  363,
#  2,
#  443,
#  14498,
#  15,
#  949,
#  40,
#  2026,
#  223,
#  151,
#  742,
#  477,
#  1819,
#  3,
#  30,
#  2986,
#  40,
#  1022,
#  5,
#  1,
#  855,
#  2,
#  4,
#  13,
#  21,
#  13,
#  5,
#  303,
#  14498,
#  15,
#  603,
#  2,
#  918,
#  11,
#  648,
#  27,
#  18,
#  348,
#  5,
#  6,
#  113,
#  2,
#  312,
#  80,
#  30,
#  3568,
#  3,
#  60,
#  26,
#  6438,
#  4187,
#  2,
#  48,
#  2,
#  30,
#  949,
#  14,
#  51,
#  2159,
#  1590,
#  68,
#  622,
#  2750,
#  26186,
#  15,
#  15644,
#  5,
#  30,
#  1,
#  10465,
#  3,
#  45,
#  200,
#  26186,
#  1461,
#  20,
#  52,
#  637,
#  1046,
#  345,
#  1775,
#  134,
#  1,
#  2582,
#  2,
#  94,
#  918,
#  12,
#  6,
#  245,
#  390,
#  446,
#  5,
#  153,
#  3,
#  1,
#  148,
#  2582,
#  2,
#  372,
#  40,
#  4580,
#  20848,
#  29,
#  9217,
#  5,
#  1,
#  941,
#  1975,
#  2,
#  372,
#  20,
#  1,
#  1132,
#  26,
#  45,
#  1729,
#  36,
#  5214,
#  15644,
#  3,
#  6,
#  144,
#  2,
#  0,
#  5,
#  34,
#  1132,
#  74,
#  9712,
#  5,
#  5826,
#  2,
#  0,
#  67,
#  62,
#  27,
#  18,
#  5,
#  44,
#  568,
#  763,
#  7,
#  176,
#  95,
#  14,
#  119,
#  918,
#  685,
#  1146,
#  79,
#  124,
#  508,
#  13043,
#  5568,
#  311,
#  7,
#  370,
#  7,
#  4107,
#  1,
#  1798,
#  7,
#  119,
#  5465,
#  918,
#  3,
#  154,
#  72,
#  39,
#  5,
#  609,
#  184,
#  20,
#  11,
#  609,
#  200,
#  95,
#  185,
#  12,
#  72,
#  6188,
#  9034,
#  12,
#  7184,
#  72,
#  1226,
#  1,
#  33801,
#  2,
#  1,
#  1798,
#  26186,
#  364,
#  89,
#  392,
#  31,
#  4779,
#  36,
#  1046,
#  67,
#  1,
#  2758,
#  42434,
#  2069,
#  30,
#  949,
#  40,
#  2026,
#  25,
#  56,
#  0,
#  9930,
#  7089,
#  142,
#  4187,
#  2,
#  30,
#  502,
#  26,
#  3236,
#  ...]

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'term', 'anarchism', 'originated', 'as', 'term', 'of', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.735400
# Nearest to these: ilm, ingots, haifa, dime, subscribed, featured, gradius, catastrophe,
# Nearest to many: astrologer, scantily, fate, liquified, millennialism, convolutions, coitus, lexis,
# Nearest to often: paints, milford, curator, wavy, fia, pollard, brandeis, bonfires,
# Nearest to the: branch, gein, general, fandoms, seasons, qualities, chemical, solstices,
# Nearest to some: gesserit, schlick, sukarnoputri, chips, piccard, eritrea, uml, tls,
# Nearest to would: motel, brakeman, dedication, rhenish, designers, felons, norodom, victims,
# Nearest to have: supermodel, protester, xiii, bargain, masculism, boundary, forty, kirwan,
# Nearest to used: faring, amplifier, unfriendly, satirizing, florence, hbox, amoxicillin, reel,
# Nearest to s: exploitable, microcomputers, gallatin, rtp, unger, entrenchment, subversion, grade,
# Nearest to who: hennecke, designator, radiocommunication, beetle, antonio, palahniuk, jansen, minivan,
# Nearest to eight: bale, juggernaut, hemp, contender, normality, cecilia, schumpeter, patrician,
# Nearest to it: prostitution, regular, beni, stains, luxembourg, orbited, scolded, alpaca,
# Nearest to over: lasts, fusion, ghz, yusuf, undetected, conscious, republicans, duval,
# Nearest to up: alphabets, fife, outs, lom, procession, grouped, distrito, tana,
# Nearest to war: commentaries, runequest, tuireadh, songwriter, frantic, semester, smokeless, knapsack,
# Nearest to into: area, shaky, defences, balaton, desilu, southern, copps, schiaparelli,
# Average loss at step 2000: 4.366731
# Average loss at step 4000: 3.871331
# Average loss at step 6000: 3.788226
# Average loss at step 8000: 3.686699
# Average loss at step 10000: 3.613617
# Nearest to these: uke, were, bifurcation, ingots, moto, faced, broker, substitutions,
# Nearest to many: some, astrologer, lexis, jars, hatches, other, bounty, mohiam,
# Nearest to often: commonly, he, conformed, paints, also, milford, sometimes, not,
# Nearest to the: a, his, its, this, their, tain, devour, attachment,
# Nearest to some: many, tls, several, rcito, hypertrophy, subscribers, coney, correspondent,
# Nearest to would: will, could, can, may, must, felons, to, pistons,
# Nearest to have: had, be, has, were, do, are, chairs, crewmembers,
# Nearest to used: faring, georgians, hellespont, gasification, akin, florence, concerned, amplifier,
# Nearest to s: his, synthesizer, sikhism, observance, kriegsmarine, walla, calculi, was,
# Nearest to who: jansen, he, nicephorus, wheeled, chased, designator, radiocommunication, johnson,
# Nearest to eight: nine, six, five, seven, four, three, zero, two,
# Nearest to it: he, this, there, she, that, which, not, hrothgar,
# Nearest to over: on, inauguration, fusion, lasts, duval, undetected, ghz, row,
# Nearest to up: alphabets, procession, extinct, fife, cio, dielectric, find, clockwork,
# Nearest to war: semester, commentaries, vought, reigned, appalachian, tuireadh, incite, articulations,
# Nearest to into: from, area, southern, defences, fundamental, nose, balaton, dicaprio,
# Average loss at step 12000: 3.606619
# Average loss at step 14000: 3.571673
# Average loss at step 16000: 3.411400
# Average loss at step 18000: 3.455393
# Average loss at step 20000: 3.540770
# Nearest to these: some, many, other, several, which, fried, the, softer,
# Nearest to many: some, several, other, all, these, astrologer, jars, lexis,
# Nearest to often: also, commonly, sometimes, it, widely, conformed, there, redneck,
# Nearest to the: its, their, this, a, his, some, devour, any,
# Nearest to some: many, several, these, all, the, tls, their, coney,
# Nearest to would: could, may, can, will, must, felons, to, should,
# Nearest to have: had, has, be, were, are, chairs, do, clean,
# Nearest to used: faring, hellespont, akin, florence, felice, able, adopted, popes,
# Nearest to s: walla, calculi, punctuation, sikhism, elway, injuring, honeys, generalship,
# Nearest to who: he, which, then, they, she, wheeled, also, nicephorus,
# Nearest to eight: nine, seven, six, four, five, three, zero, two,
# Nearest to it: he, this, there, she, which, they, often, not,
# Nearest to over: yusuf, let, duval, row, on, lasts, ucs, locks,
# Nearest to up: procession, alphabets, extinct, fife, clockwork, usable, periphery, maid,
# Nearest to war: semester, incite, commentaries, shale, shimon, formalism, reaffirm, encloses,
# Nearest to into: from, hofmann, area, freeza, fundamental, circle, dicaprio, on,
# Average loss at step 22000: 3.505805
# Average loss at step 24000: 3.486198
# Average loss at step 26000: 3.479754
# Average loss at step 28000: 3.478506
# Average loss at step 30000: 3.501335
# Nearest to these: some, many, several, their, such, all, those, which,
# Nearest to many: some, several, these, various, other, lexis, tats, such,
# Nearest to often: sometimes, also, commonly, widely, generally, still, there, now,
# Nearest to the: its, their, his, a, some, molybdenum, devour, many,
# Nearest to some: many, several, these, all, their, the, most, tls,
# Nearest to would: can, will, could, may, must, should, might, cannot,
# Nearest to have: had, has, were, be, are, having, chairs, clean,
# Nearest to used: known, regarded, written, hellespont, included, faring, able, akin,
# Nearest to s: his, idiosyncratic, synthesizer, isbn, honeys, trip, walla, whose,
# Nearest to who: he, they, which, she, wheeled, jansen, and, also,
# Nearest to eight: nine, seven, six, five, four, three, zero, two,
# Nearest to it: he, there, this, she, they, which, not, secam,
# Nearest to over: through, row, yusuf, whither, duval, rapier, colophon, on,
# Nearest to up: procession, alphabets, them, clockwork, him, fife, favours, back,
# Nearest to war: semester, incite, pipes, shale, encloses, commentaries, reaffirm, groundwater,
# Nearest to into: from, under, hofmann, prep, freeza, fundamental, down, asparagales,
# Average loss at step 32000: 3.499280
# Average loss at step 34000: 3.486946
# Average loss at step 36000: 3.457118
# Average loss at step 38000: 3.300310
# Average loss at step 40000: 3.426955
# Nearest to these: many, some, several, such, both, those, which, their,
# Nearest to many: some, several, these, various, those, such, both, were,
# Nearest to often: commonly, sometimes, also, widely, usually, generally, still, now,
# Nearest to the: their, its, a, his, this, any, smart, devour,
# Nearest to some: many, several, these, any, their, both, various, most,
# Nearest to would: will, could, can, may, must, should, might, cannot,
# Nearest to have: has, had, were, are, be, marwan, reminded, convenient,
# Nearest to used: known, found, included, able, regarded, described, referred, written,
# Nearest to s: trip, whose, his, frontispiece, vertically, gigue, walla, gamsakhurdia,
# Nearest to who: he, which, she, that, they, often, jansen, and,
# Nearest to eight: nine, seven, four, six, five, three, zero, two,
# Nearest to it: he, she, there, this, they, which, but, actually,
# Nearest to over: through, row, undetected, whither, decades, lasts, duval, shaku,
# Nearest to up: them, procession, back, him, out, down, obscured, favours,
# Nearest to war: incite, shale, reaffirm, solanas, pipes, semester, bromley, commentaries,
# Nearest to into: from, freeza, through, dicaprio, down, tuning, paradigmatic, nose,
# Average loss at step 42000: 3.434244
# Average loss at step 44000: 3.453179
# Average loss at step 46000: 3.452667
# Average loss at step 48000: 3.351067
# Average loss at step 50000: 3.385316
# Nearest to these: some, many, both, several, those, such, their, various,
# Nearest to many: some, several, these, both, various, such, most, other,
# Nearest to often: sometimes, commonly, generally, also, usually, widely, now, still,
# Nearest to the: its, their, a, this, his, some, conductors, any,
# Nearest to some: many, several, these, both, various, most, any, dealings,
# Nearest to would: will, could, can, may, must, should, might, cannot,
# Nearest to have: had, has, were, be, are, reminded, include, according,
# Nearest to used: known, able, written, available, referred, regarded, described, found,
# Nearest to s: isbn, synthesizer, whose, his, fist, and, wimbledon, zeno,
# Nearest to who: he, which, she, they, freed, wheeled, also, there,
# Nearest to eight: six, seven, nine, four, five, three, zero, two,
# Nearest to it: he, she, there, this, they, soon, sorting, which,
# Nearest to over: through, on, lasts, israelite, cubist, colophon, promising, marx,
# Nearest to up: them, out, back, off, procession, down, him, favours,
# Nearest to war: incite, bromley, mercalli, saxo, shale, pipes, groundwater, semester,
# Nearest to into: from, through, freeza, under, asparagales, down, dicaprio, prep,
# Average loss at step 52000: 3.433722
# Average loss at step 54000: 3.427625
# Average loss at step 56000: 3.435363
# Average loss at step 58000: 3.398395
# Average loss at step 60000: 3.397670
# Nearest to these: many, some, those, several, both, such, which, all,
# Nearest to many: some, several, various, these, both, most, all, such,
# Nearest to often: sometimes, commonly, usually, generally, also, widely, now, currently,
# Nearest to the: a, their, its, some, this, these, any, his,
# Nearest to some: many, several, these, any, various, most, both, the,
# Nearest to would: will, could, may, can, must, should, might, cannot,
# Nearest to have: had, has, be, were, are, include, having, mentats,
# Nearest to used: known, written, described, regarded, called, available, found, seen,
# Nearest to s: synthesizer, walla, whose, palestrina, isbn, although, bored, kriegsmarine,
# Nearest to who: which, he, now, she, they, johnson, mechanic, wheeled,
# Nearest to eight: nine, seven, six, four, five, three, zero, two,
# Nearest to it: he, there, this, she, they, which, what, soon,
# Nearest to over: through, around, on, into, lasts, in, pronged, promising,
# Nearest to up: back, off, out, them, down, him, procession, favours,
# Nearest to war: retaliated, incite, groundwater, mercalli, bromley, pipes, shale, solanas,
# Nearest to into: from, through, over, prep, within, under, across, copps,
# Average loss at step 62000: 3.241754
# Average loss at step 64000: 3.254720
# Average loss at step 66000: 3.402646
# Average loss at step 68000: 3.400471
# Average loss at step 70000: 3.355581
# Nearest to these: many, such, some, those, several, are, their, the,
# Nearest to many: some, several, various, these, all, both, most, such,
# Nearest to often: sometimes, usually, commonly, generally, now, also, frequently, widely,
# Nearest to the: their, its, any, this, a, our, these, some,
# Nearest to some: many, several, these, all, both, any, various, most,
# Nearest to would: will, could, may, can, should, must, might, cannot,
# Nearest to have: had, has, are, were, include, be, according, having,
# Nearest to used: known, written, available, referred, regarded, described, included, found,
# Nearest to s: isbn, kriegsmarine, gto, whose, boomerangs, the, gamsakhurdia, lycus,
# Nearest to who: he, which, she, mechanic, corrupt, never, johnson, traditionalist,
# Nearest to eight: nine, six, seven, four, five, three, zero, one,
# Nearest to it: he, she, there, this, they, which, still, we,
# Nearest to over: through, shaku, around, on, functionalists, marx, abv, brimstone,
# Nearest to up: off, out, them, back, down, procession, him, alphabets,
# Nearest to war: battle, retaliated, groundwater, bromley, shale, mercalli, reaffirm, semester,
# Nearest to into: from, through, asparagales, schiaparelli, copps, within, under, prep,
# Average loss at step 72000: 3.372164
# Average loss at step 74000: 3.349125
# Average loss at step 76000: 3.319364
# Average loss at step 78000: 3.348425
# Average loss at step 80000: 3.380063
# Nearest to these: those, several, many, such, some, both, various, which,
# Nearest to many: some, several, various, these, both, most, numerous, all,
# Nearest to often: sometimes, usually, commonly, generally, typically, frequently, now, also,
# Nearest to the: its, their, his, this, her, hin, notations, a,
# Nearest to some: many, several, various, most, both, these, all, any,
# Nearest to would: will, could, may, can, should, must, might, cannot,
# Nearest to have: had, has, are, be, were, include, having, reminded,
# Nearest to used: known, written, referred, available, regarded, included, called, seen,
# Nearest to s: elway, isbn, his, gigue, lycus, sheila, hosni, annihilation,
# Nearest to who: he, she, they, never, mechanic, which, wheeled, johnson,
# Nearest to eight: nine, six, seven, five, four, three, zero, two,
# Nearest to it: he, she, there, this, they, we, still, not,
# Nearest to over: around, through, into, off, across, shaku, between, overlying,
# Nearest to up: out, off, back, them, down, procession, him, distrito,
# Nearest to war: battle, bromley, chung, incite, installation, retaliated, groundwater, semester,
# Nearest to into: through, from, schiaparelli, asparagales, over, prep, down, within,
# Average loss at step 82000: 3.406116
# Average loss at step 84000: 3.407724
# Average loss at step 86000: 3.388465
# Average loss at step 88000: 3.351032
# Average loss at step 90000: 3.367888
# Nearest to these: several, many, some, those, such, are, which, instead,
# Nearest to many: several, some, various, these, numerous, both, all, most,
# Nearest to often: sometimes, commonly, usually, generally, now, also, typically, frequently,
# Nearest to the: its, his, this, their, any, a, zion, every,
# Nearest to some: many, several, these, most, any, various, certain, both,
# Nearest to would: will, could, may, can, should, might, must, cannot,
# Nearest to have: had, has, were, be, are, having, include, provide,
# Nearest to used: known, referred, written, regarded, described, available, able, called,
# Nearest to s: isbn, whose, unveiling, his, wimbledon, annihilation, synthesizer, elway,
# Nearest to who: he, which, she, already, often, never, but, anglorum,
# Nearest to eight: seven, nine, six, five, four, three, zero, two,
# Nearest to it: he, she, there, this, they, often, we, itself,
# Nearest to over: around, through, off, buttocks, across, overlying, decades, within,
# Nearest to up: out, off, back, down, them, procession, him, achish,
# Nearest to war: battle, bromley, installation, retaliated, pipes, groundwater, shale, during,
# Nearest to into: through, from, prep, asparagales, schiaparelli, down, under, via,
# Average loss at step 92000: 3.399625
# Average loss at step 94000: 3.251966
# Average loss at step 96000: 3.357206
# Average loss at step 98000: 3.248699
# Average loss at step 100000: 3.362289
# Nearest to these: several, some, many, those, various, instead, their, all,
# Nearest to many: several, some, these, various, numerous, few, all, those,
# Nearest to often: sometimes, usually, commonly, generally, typically, frequently, now, widely,
# Nearest to the: their, its, his, your, a, our, calculi, dai,
# Nearest to some: many, several, these, any, various, all, certain, most,
# Nearest to would: will, could, might, may, can, should, must, cannot,
# Nearest to have: had, has, are, include, were, be, tend, having,
# Nearest to used: written, referred, known, applied, stored, available, found, described,
# Nearest to s: whose, hosni, his, isbn, sigurd, lycus, authorised, liberating,
# Nearest to who: he, she, never, which, already, always, hatta, and,
# Nearest to eight: seven, nine, six, four, five, three, zero, two,
# Nearest to it: he, she, this, there, they, often, which, actually,
# Nearest to over: around, across, through, within, between, shaku, brimstone, off,
# Nearest to up: off, out, back, them, down, him, procession, together,
# Nearest to war: battle, groundwater, installation, retaliated, incite, mercalli, connelly, syllabaries,
# Nearest to into: through, from, prep, within, across, asparagales, schiaparelli, under,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
